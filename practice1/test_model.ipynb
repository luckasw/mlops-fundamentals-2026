# %%
import pickle
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import root_mean_squared_error, r2_score

# %%
with open("rfr_model.pkl", "rb") as f:
    model = pickle.load(f)

df = pd.read_parquet("clean_tripdata_v2.parquet")

# %%
X = df[["trip_distance", "pickup_hour", "trip_duration", "pickup_day_of_week"]]
y = df["total_amount"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=11)

y_pred = model.predict(X_test)

mse = root_mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"RMSE - {mse}\nR2 score - {r2}")
# Out:
# RMSE - 4.228507841631464
# R2 score - 0.9040582693131516

# %% [markdown]
# ## Old scores
#
# RMSE - 5.209677543060735
#
# R2 score - 0.8563294462847166

# %% [markdown]
# It seems that the scores have improved!
